# %% [markdown]
# ### Setup Mongodb database

# %%
import pandas as pd
import pymongo

# %%
df = pd.read_csv('Amazon_Fashion_Dataset.csv')

# %%
df.head()
# Out:
#       item_id                       user_id  rating  \
# 0  B074DRXHB3  AG2BJOE43JDTA64QMYS6WLUS37WA     4.0
# 1  B09DY37VMS  AHV6QCNBJNSGLATP56JAWJ3C4G2A     4.0
# 2  B09WL4GSH9  AHV6QCNBJNSGLATP56JAWJ3C4G2A     5.0
# 3  B01IX33TWG  AHV6QCNBJNSGLATP56JAWJ3C4G2A     5.0
# 4  B012O733N2  AHV6QCNBJNSGLATP56JAWJ3C4G2A     4.0
#
#                                                image
# 0  https://m.media-amazon.com/images/I/81IyJwwxBN...
# 1  https://m.media-amazon.com/images/I/01RmK+J4pJ...
# 2  https://m.media-amazon.com/images/I/51XjoiUL8V...
# 3  https://m.media-amazon.com/images/I/81NuH+v+0H...
# 4  https://m.media-amazon.com/images/I/61yuSoLmpW...

# %%
# df should be converted into dict before we push it to mongodb
data = df.to_dict(orient='records')

# %%
# Check the connection is establish or not
from pymongo import MongoClient

try:
    client = MongoClient("mongodb+srv://ankur0007:DjmVy5QsNEdKGRrF@cluster0.3m6g2.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
    client.admin.command('ping')  # Test connection
    print("Connection successful!")
except Exception as e:
    print(f"Connection error: {e}")
# Out:
# Connection successful!

# %%
# Setting Up MongoDB Databse  
DB_NAME = "Adversial_Multimedia_Recommendation"
COLLECTION_NAME = "Adversial_Multimedia_Recommendation-Data"
CONNECTION_URL = "mongodb+srv://ankur0007:DjmVy5QsNEdKGRrF@cluster0.3m6g2.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
# Uploading data to MongoDB
rec = collection.insert_many(data)

# %%
collection.find()

# %%
list(collection.find())
# Out:
# [{'_id': ObjectId('67863876128591b70c0a060d'),
#   'item_id': 'B074DRXHB3',
#   'user_id': 'AG2BJOE43JDTA64QMYS6WLUS37WA',
#   'rating': 4.0,
#   'image': 'https://m.media-amazon.com/images/I/81IyJwwxBNL._AC_UL1500_.jpg'},
#  {'_id': ObjectId('67863876128591b70c0a060e'),
#   'item_id': 'B09DY37VMS',
#   'user_id': 'AHV6QCNBJNSGLATP56JAWJ3C4G2A',
#   'rating': 4.0,
#   'image': 'https://m.media-amazon.com/images/I/01RmK+J4pJL._AC_.gif'},
#  {'_id': ObjectId('67863876128591b70c0a060f'),
#   'item_id': 'B09WL4GSH9',
#   'user_id': 'AHV6QCNBJNSGLATP56JAWJ3C4G2A',
#   'rating': 5.0,
#   'image': 'https://m.media-amazon.com/images/I/51XjoiUL8VL._AC_UL1000_.jpg'},
#  {'_id': ObjectId('67863876128591b70c0a0610'),
#   'item_id': 'B01IX33TWG',
#   'user_id': 'AHV6QCNBJNSGLATP56JAWJ3C4G2A',
#   'rating': 5.0,
#   'image': 'https://m.media-amazon.com/images/I/81NuH+v+0HL._AC_UL1500_.jpg'},
#  {'_id': ObjectId('67863876128591b70c0a0611'),
#   'item_id': 'B012O733N2',
# ...

# %%
df1 = pd.DataFrame(list(collection.find()))

# %%
df1.head()
# Out:
#                         _id     item_id                       user_id  rating  \
# 0  67863876128591b70c0a060d  B074DRXHB3  AG2BJOE43JDTA64QMYS6WLUS37WA     4.0
# 1  67863876128591b70c0a060e  B09DY37VMS  AHV6QCNBJNSGLATP56JAWJ3C4G2A     4.0
# 2  67863876128591b70c0a060f  B09WL4GSH9  AHV6QCNBJNSGLATP56JAWJ3C4G2A     5.0
# 3  67863876128591b70c0a0610  B01IX33TWG  AHV6QCNBJNSGLATP56JAWJ3C4G2A     5.0
# 4  67863876128591b70c0a0611  B012O733N2  AHV6QCNBJNSGLATP56JAWJ3C4G2A     4.0
#
#                                                image
# 0  https://m.media-amazon.com/images/I/81IyJwwxBN...
# 1  https://m.media-amazon.com/images/I/01RmK+J4pJ...
# 2  https://m.media-amazon.com/images/I/51XjoiUL8V...
# 3  https://m.media-amazon.com/images/I/81NuH+v+0H...
# 4  https://m.media-amazon.com/images/I/61yuSoLmpW...

# %%
df1.columns.to_list()
# Out:
# ['_id', 'item_id', 'user_id', 'rating', 'image']
